# %%
# Import Libraries
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import time
# A class that models the Neural Net with L-layers and
# N neurons in each layer. It also contains the functions
# for training, testing, and optimizing the Neural Network

np.random.seed(100)

class DeepNN:

    # Constructor to build the structure of the Neural Network
    # It accepts the layers in the format of [2,3,1] -> 2 Neuron Input Layer,
    # 3 Neuron Hidden Layer and 1 Neuron output layer
    def __init__(self, layers, activations, epsilon = 0.55):
        ############################### Initialize the number of layers and neurons
        self.layers = layers
        self.num_layers = len(layers)
        self.hidden_layers = len(layers) - 2
        self.input_neurons = layers[0]
        self.output_neurons = layers[-1]

        ########## Intialize parameters for Forward Propogation
        # Initialize Weights
        self.epsilon = epsilon  # Random Weight Initialization Factor
        self.weights = []
        for i in range(self.num_layers-2):
            self.weights.append(np.random.randn(layers[i]+1, layers[i+1]+1)*2*self.epsilon - self.epsilon)
                        # We add a +1 to incorporate for weights from the +1 neuron for the bias
        self.weights.append(np.random.randn(layers[-2]+1, layers[-1])*2*self.epsilon - self.epsilon)

        self.a = [] # To keep track of activations
        self.z = [] # To keep track of layer values
        self.activations = activations # Activations for each layer

        ######### Intialize parameters for Backward Propogation
        self.delta = []
        self.gradient = []

        # Initialize Scaling
        self.scaler = preprocessing.StandardScaler()

    ################################### Define Some Activation Functions and their derivatives ##################
    def sigmoid(self,x):
        return 1.0/(1.0 + np.exp(-x))

    def sigmoidPrime(self,x):
        return self.sigmoid(x)*(1-self.sigmoid(x))

    def reLU(self,x):
        return np.maximum(x, 0)

    def reLUPrime(self,x):
        return np.where(x > 0, 1.0, 0.0)

    def softmax(self,x):
        return np.exp(x)/np.sum(np.exp(x), axis = 0)

    def tanh(self,x):
        return np.tanh(x)

    def tanh_prime(self,x):
        return 1 - np.power(np.tanh(x),2)

    def identity(self,x):
        return x

    def identity_prime(self,x):
        return 1

    ######################################### Cost Functions #############################################
    # Least Squares
    def least_squares_cost(self,t):
        return 0.5*np.mean( (t-self.a[-1])**2 )

    # Cross Entropy Log Loss Function
    def log_loss(self,t):
        return np.mean( np.nan_to_num( -1*t*np.log(self.a[-1]) - (1-t)*np.log(1-self.a[-1]) ) )

    ######################################### Forward Feed ##############################################
    def forwardFeed(self, X):
        a = [X] # Keep Track of activations
        z = []

        # Add Bias
        c = np.ones([1,a[0].shape[0]]).reshape(a[0].shape[0],1)
        a[0] = np.concatenate((c,a[0]), axis=1)
#         print(a)
        for i in range(self.num_layers-1):
#             print(a[i])
            z.append(np.dot(a[i],self.weights[i]))
            if(self.activations[i] == 'sigmoid'):
                a.append(self.sigmoid(z[i]))
            elif(self.activations[i] == 'reLU'):
                a.append(self.reLU(z[i]))
            elif(self.activations[i] == 'tanh'):
                a.append(self.tanh(z[i]))
            elif(self.activations[i] == 'softmax'):
                a.append(self.softmax(z[i]))
            elif(self.activations[i] == 'identity'):
                a.append(self.identity(z[i]))
        self.a = a
        self.z = z

    def backPropogate(self,y):

        delta = []
        gradient = []
        weights_flipped = self.weights[::-1]
        z_flipped = self.z[::-1]
        activations_flipped = self.a[::-1]
        activation_func_flipped = self.activations[::-1]
        delta.append(activations_flipped[0] - y)
        for i in range(0,self.num_layers-2):
                if(activation_func_flipped[i] == 'sigmoid'):
                    delta.append( np.dot(delta[i], weights_flipped[i].T ) * self.sigmoidPrime(z_flipped[i+1]) )
                elif(activation_func_flipped[i] == 'reLU'):
                    delta.append( np.dot(delta[i], weights_flipped[i].T ) * self.reLUPrime(z_flipped[i+1]) )
                elif(activation_func_flipped[i] == 'tanh'):
                    delta.append( np.dot(delta[i], weights_flipped[i].T ) * self.tanh_prime(z_flipped[i+1]) )
                elif(activation_func_flipped[i] == 'identity'):
                    delta.append( np.dot(delta[i], weights_flipped[i].T ) * self.identity_prime(z_flipped[i+1]) )
                elif(activation_func_flipped[i] == 'softmax'):
                    delta.append( np.dot(delta[i], weights_flipped[i].T))

        delta = delta[::-1]

        for i in range(len(delta)):
            gradient.append( np.dot(self.a[i].T, delta[i]) )
            
        self.delta = delta
        self.gradient = gradient

    def learn(self, epochs, learning_rate, X, y, cost_func, metrics_at=10, optimizer = '', batch_size=10, scaler_type='standard_scaler', split=False, test_size=0.25, beta = 0.9, beta_2 = 0.99, epsilon=10e-8):
        start = time.time()
        
        cost=[]
        
        v_n = []
        s_n = []
        for j in range(len(self.weights)):
            v_n.append(np.zeros(self.weights[j].shape))
            s_n.append(np.zeros(self.weights[j].shape))
            
        if scaler_type == 'min_max_scaler':
            self.scaler = preprocessing.MinMaxScaler()
        X = self.scaler.fit_transform(X)

        if split:
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=0)
            X = X_train
            y = y_train

        
        for i in range(epochs):
                if optimizer == 'mini_batch':
                    # Batch size of 1 makes it SGD
                    no_of_batches = int(len(X)/batch_size)
                    for k in range(no_of_batches):
                        if k==no_of_batches-1:
                            X_sgd = X[k*batch_size:]
                            y_sgd = y[k*batch_size:]
                        else:
                            X_sgd = X[k*batch_size:(k+1)*batch_size]
                            y_sgd = y[k*batch_size:(k+1)*batch_size]
                        self.forwardFeed(X_sgd)
                        self.backPropogate(y_sgd)
                        for j in range(len(self.gradient)):
                            v_n[j] = beta * v_n[j] + (1-beta) * self.gradient[j]
                            self.weights[j] = self.weights[j] - learning_rate * v_n[j]
                elif optimizer == 'rmsprop':
                    # Batch size of 1 makes it SGD
                    no_of_batches = int(len(X)/batch_size)
                    for k in range(no_of_batches):
                        if k==no_of_batches-1:
                            X_sgd = X[k*batch_size:]
                            y_sgd = y[k*batch_size:]
                        else:
                            X_sgd = X[k*batch_size:(k+1)*batch_size]
                            y_sgd = y[k*batch_size:(k+1)*batch_size]
                            
                        self.forwardFeed(X_sgd)
                        self.backPropogate(y_sgd)
                        for j in range(len(self.gradient)):
                            s_n[j] = beta_2 * s_n[j] + (1-beta_2) * np.power(self.gradient[j],2)
                            self.weights[j] = self.weights[j] - learning_rate * self.gradient[j]/np.sqrt(s_n[j]+epsilon)
                elif optimizer == 'adam':
                    # Batch size of 1 makes it SGD
                    no_of_batches = int(len(X)/batch_size)
                    for k in range(no_of_batches):
                        if k==no_of_batches-1:
                            X_sgd = X[k*batch_size:]
                            y_sgd = y[k*batch_size:]
                        else:
                            X_sgd = X[k*batch_size:(k+1)*batch_size]
                            y_sgd = y[k*batch_size:(k+1)*batch_size]
                        self.forwardFeed(X_sgd)
                        self.backPropogate(y_sgd)
                        for j in range(len(self.gradient)):
                            v_n[j] = beta * v_n[j] + (1-beta) * self.gradient[j]
                            s_n[j] = beta_2 * s_n[j] + (1-beta_2) * np.power(self.gradient[j],2)
                            
                            # Beta Correction
                            v_n[j] = v_n[j] / (1-np.power(beta,k)+epsilon)
                            s_n[j] = s_n[j] / (1-np.power(beta_2,k)+epsilon)
                            
                            self.weights[j] = self.weights[j] - learning_rate * v_n[j]/np.sqrt(s_n[j]+epsilon)

                else:
                    self.forwardFeed(X)
                    self.backPropogate(y)
                    for j in range(len(self.gradient)):
                        self.weights[j] = self.weights[j] - learning_rate * self.gradient[j]

                if(i%metrics_at == 0):
                    self.forwardFeed(X)
                    print('Effective epoch: ', i/metrics_at + 1)
                    if(cost_func == 'log_loss'):
                        cost.append(self.log_loss(y))
                        print('Accuracy: ', np.mean(np.round(self.think(X))==y) * 100, '%')
                    elif(cost_func == 'least_squares'):
                        cost.append(self.least_squares_cost(y))
                    print('Cost: ', cost[-1], '\n')

        

        end = time.time()
        
        
        if(cost_func == 'log_loss' and split):
            print('Testing Accuracy: ', np.mean(np.round(self.think(X_test))==y_test) * 100, '%')
        plt.plot(cost)
        print('Time Taken: ', end-start, ' seconds')
        return self.weights

    def think(self,X):
#         X = self.scaler.fit_transform(X)
        a = [X] # Keep Track of activations
        z = []

        # Add Bias
        c = np.ones([1,a[0].shape[0]]).reshape(a[0].shape[0],1)
        a[0] = np.concatenate((c,a[0]), axis=1)
#         print(a)
        for i in range(self.num_layers-1):
#             print(a[i])
            z.append(np.dot(a[i],self.weights[i]))
            if(self.activations[i] == 'sigmoid'):
                a.append(self.sigmoid(z[i]))
            elif(self.activations[i] == 'reLU'):
                a.append(self.reLU(z[i]))
            elif(self.activations[i] == 'tanh'):
                a.append(self.tanh(z[i]))
            elif(self.activations[i] == 'softmax'):
                a.append(self.softmax(z[i]))
            elif(self.activations[i] == 'identity'):
                a.append(self.identity(z[i]))
                
        return a[-1]

# %%
########################## Part a) - Generate Dataset
X = np.array([[-1, -1],[1, 1],[-1, 1],[1, -1]],dtype='float')
t = np.array([1, 1, 0, 0],dtype='float').reshape(4,1)


NN = DeepNN([2,2,1], activations=['tanh','sigmoid'], epsilon = 0.12)

w = NN.learn(epochs=1500, learning_rate=0.1, X=X, y=t, cost_func='log_loss', metrics_at=1, split=False)
plt.title('XOR Cost Function')
print('Accuracy: ',np.mean(np.round(NN.think(X))==t) * 100)


x_mesh = np.linspace(-1.2,1.2,30).reshape(30,1)
y_mesh = np.linspace(-1.2,1.2,30).reshape(30,1)

X_mesh, Y_mesh = np.meshgrid(x_mesh,x_mesh)
X_test = np.hstack((x_mesh,y_mesh))



# Classify Points for Decision Boundary
predicitions = np.zeros([len(x_mesh),len(y_mesh)])
for i in range(len(X_mesh)):
    for j in range(len(Y_mesh)):
        pnt = np.array([X_mesh[i,j],Y_mesh[i,j]]).reshape(1,2)
        predicitions[i,j] = NN.think(pnt)[0,0]



import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X_mesh, Y_mesh, predicitions-0.5,1000)

x_xor = [-1, 1, -1, 1]
y_xor = [-1, 1, 1, -1]
t_xor = [0.5, 0.5, -0.5, -0.5]
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.scatter(x_xor, y_xor, t_xor, c='r')
plt.title('XOR Decision Surface using Logistic Sigmoid')
# Out:
# Effective epoch:  1.0
# Accuracy:  25.0 %
# Cost:  0.6976543555934396
#
# Effective epoch:  2.0
# Accuracy:  25.0 %
# Cost:  0.6972792892906747
#
# Effective epoch:  3.0
# Accuracy:  25.0 %
# Cost:  0.6969309081210856
#
# Effective epoch:  4.0
# Accuracy:  25.0 %
# Cost:  0.6966069669166609
#
# Effective epoch:  5.0
# Accuracy:  25.0 %
# Cost:  0.6963054393037207
#
# Effective epoch:  6.0
# Accuracy:  25.0 %
# Cost:  0.6960244928145412
#
# Effective epoch:  7.0
# Accuracy:  25.0 %
# Cost:  0.6957624672205207
#
# Effective epoch:  8.0
# Accuracy:  25.0 %
# Cost:  0.6955178556249954
#
# Effective epoch:  9.0
# Accuracy:  25.0 %
# Cost:  0.6952892879257484
#
# Effective epoch:  10.0
# Accuracy:  25.0 %
# Cost:  0.6950755163171904
#
# Effective epoch:  11.0
# Accuracy:  25.0 %
# Cost:  0.6948754025522097
#
# Effective epoch:  12.0
# Accuracy:  25.0 %
# Cost:  0.6946879067255799
#
# Effective epoch:  13.0
# Accuracy:  25.0 %
# Cost:  0.6945120773759619
#
# Effective epoch:  14.0
# Accuracy:  25.0 %
# Cost:  0.6943470427330959
#
# Effective epoch:  15.0
# Accuracy:  25.0 %
# Cost:  0.6941920029617095
#
# Effective epoch:  16.0
# Accuracy:  25.0 %
# Cost:  0.6940462232747339
#
# Effective epoch:  17.0
# Accuracy:  25.0 %
# Cost:  0.6939090278062663
#
# Effective epoch:  18.0
# Accuracy:  25.0 %
# Cost:  0.6937797941498589
#
# Effective epoch:  19.0
# Accuracy:  25.0 %
# Cost:  0.6936579484806131
#
# Effective epoch:  20.0
# Accuracy:  25.0 %
# Cost:  0.6935429611905327
#
# Effective epoch:  21.0
# Accuracy:  25.0 %
# Cost:  0.6934343429759899
#
# Effective epoch:  22.0
# Accuracy:  25.0 %
# Cost:  0.6933316413241831
#
# Effective epoch:  23.0
# Accuracy:  25.0 %
# Cost:  0.6932344373523688
#
# Effective epoch:  24.0
# Accuracy:  25.0 %
# Cost:  0.6931423429595674
#
# Effective epoch:  25.0
# Accuracy:  25.0 %
# Cost:  0.693054998255548
#
# Effective epoch:  26.0
# Accuracy:  25.0 %
# Cost:  0.6929720692362953
#
# Effective epoch:  27.0
# Accuracy:  25.0 %
# Cost:  0.692893245678972
#
# Effective epoch:  28.0
# Accuracy:  25.0 %
# Cost:  0.692818239232671
#
# Effective epoch:  29.0
# Accuracy:  25.0 %
# Cost:  0.692746781684118
#
# Effective epoch:  30.0
# Accuracy:  25.0 %
# Cost:  0.6926786233799631
#
# Effective epoch:  31.0
# Accuracy:  25.0 %
# Cost:  0.6926135317894555
#
# Effective epoch:  32.0
# Accuracy:  25.0 %
# Cost:  0.6925512901931782
#
# Effective epoch:  33.0
# Accuracy:  25.0 %
# Cost:  0.692491696485166
#
# Effective epoch:  34.0
# Accuracy:  25.0 %
# Cost:  0.6924345620771599
#
# Effective epoch:  35.0
# Accuracy:  25.0 %
# Cost:  0.6923797108950152
#
# Effective epoch:  36.0
# Accuracy:  25.0 %
# Cost:  0.6923269784583765
#
# Effective epoch:  37.0
# Accuracy:  50.0 %
# Cost:  0.6922762110357076
#
# Effective epoch:  38.0
# Accuracy:  50.0 %
# Cost:  0.6922272648676142
#
# Effective epoch:  39.0
# Accuracy:  50.0 %
# Cost:  0.692180005452148
#
# Effective epoch:  40.0
# Accuracy:  50.0 %
# Cost:  0.6921343068864423
#
# Effective epoch:  41.0
# Accuracy:  50.0 %
# Cost:  0.6920900512596166
#
# Effective epoch:  42.0
# Accuracy:  50.0 %
# Cost:  0.6920471280924049
#
# Effective epoch:  43.0
# Accuracy:  50.0 %
# Cost:  0.6920054338194195
#
# Effective epoch:  44.0
# Accuracy:  50.0 %
# Cost:  0.6919648713103705
#
# Effective epoch:  45.0
# Accuracy:  50.0 %
# Cost:  0.6919253494269261
#
# Effective epoch:  46.0
# Accuracy:  50.0 %
# Cost:  0.6918867826122113
#
# Effective epoch:  47.0
# Accuracy:  50.0 %
# Cost:  0.6918490905102423
#
# Effective epoch:  48.0
# Accuracy:  50.0 %
# Cost:  0.6918121976128395
#
# Effective epoch:  49.0
# Accuracy:  50.0 %
# Cost:  0.6917760329317942
#
# Effective epoch:  50.0
# Accuracy:  50.0 %
# Cost:  0.6917405296942718
#
# Effective epoch:  51.0
# Accuracy:  50.0 %
# Cost:  0.6917056250596108
#
# Effective epoch:  52.0
# Accuracy:  50.0 %
# Cost:  0.69167125985585
#
# Effective epoch:  53.0
# Accuracy:  50.0 %
# Cost:  0.691637378334454
#
# Effective epoch:  54.0
# Accuracy:  50.0 %
# Cost:  0.6916039279418522
#
# Effective epoch:  55.0
# Accuracy:  50.0 %
# Cost:  0.6915708591065131
#
# Effective epoch:  56.0
# Accuracy:  50.0 %
# Cost:  0.6915381250403949
#
# Effective epoch:  57.0
# Accuracy:  50.0 %
# Cost:  0.691505681553706
#
# Effective epoch:  58.0
# Accuracy:  50.0 %
# Cost:  0.6914734868819946
#
# Effective epoch:  59.0
# Accuracy:  50.0 %
# Cost:  0.6914415015246759
#
# Effective epoch:  60.0
# Accuracy:  50.0 %
# Cost:  0.6914096880941646
#
# Effective epoch:  61.0
# Accuracy:  50.0 %
# Cost:  0.6913780111748612
#
# Effective epoch:  62.0
# Accuracy:  50.0 %
# Cost:  0.6913464371912859
#
# Effective epoch:  63.0
# Accuracy:  50.0 %
# Cost:  0.6913149342847221
#
# Effective epoch:  64.0
# Accuracy:  50.0 %
# Cost:  0.6912834721977704
#
# Effective epoch:  65.0
# Accuracy:  50.0 %
# Cost:  0.6912520221662635
#
# Effective epoch:  66.0
# Accuracy:  50.0 %
# Cost:  0.6912205568180373
#
# Effective epoch:  67.0
# Accuracy:  50.0 %
# Cost:  0.691189050078086
#
# Effective epoch:  68.0
# Accuracy:  50.0 %
# Cost:  0.6911574770796651
#
# Effective epoch:  69.0
# Accuracy:  50.0 %
# Cost:  0.6911258140809415
#
# Effective epoch:  70.0
# Accuracy:  50.0 %
# Cost:  0.6910940383868134
#
# Effective epoch:  71.0
# Accuracy:  50.0 %
# Cost:  0.6910621282755565
#
# Effective epoch:  72.0
# Accuracy:  50.0 %
# Cost:  0.6910300629299695
#
# Effective epoch:  73.0
# Accuracy:  50.0 %
# Cost:  0.6909978223727239
#
# Effective epoch:  74.0
# Accuracy:  50.0 %
# Cost:  0.6909653874056338
#
# Effective epoch:  75.0
# Accuracy:  50.0 %
# Cost:  0.6909327395525932
#
# Effective epoch:  76.0
# Accuracy:  50.0 %
# Cost:  0.6908998610059305
#
# Effective epoch:  77.0
# Accuracy:  50.0 %
# Cost:  0.6908667345759645
#
# Effective epoch:  78.0
# Accuracy:  50.0 %
# Cost:  0.6908333436435433
#
# Effective epoch:  79.0
# Accuracy:  50.0 %
# Cost:  0.6907996721153781
#
# Effective epoch:  80.0
# Accuracy:  50.0 %
# Cost:  0.690765704381982
#
# Effective epoch:  81.0
# Accuracy:  50.0 %
# Cost:  0.690731425278051
#
# Effective epoch:  82.0
# Accuracy:  50.0 %
# Cost:  0.6906968200451208
#
# Effective epoch:  83.0
# Accuracy:  50.0 %
# Cost:  0.6906618742963548
#
# Effective epoch:  84.0
# Accuracy:  50.0 %
# Cost:  0.6906265739833243
#
# Effective epoch:  85.0
# Accuracy:  50.0 %
# Cost:  0.6905909053646481
#
# Effective epoch:  86.0
# Accuracy:  25.0 %
# Cost:  0.6905548549763731
#
# Effective epoch:  87.0
# Accuracy:  25.0 %
# Cost:  0.6905184096039796
#
# Effective epoch:  88.0
# Accuracy:  25.0 %
# Cost:  0.6904815562559057
#
# Effective epoch:  89.0
# Accuracy:  25.0 %
# Cost:  0.6904442821384915
#
# Effective epoch:  90.0
# Accuracy:  25.0 %
# Cost:  0.6904065746322484
#
# Effective epoch:  91.0
# Accuracy:  25.0 %
# Cost:  0.6903684212693666
#
# Effective epoch:  92.0
# Accuracy:  25.0 %
# Cost:  0.6903298097123779
#
# Effective epoch:  93.0
# Accuracy:  25.0 %
# Cost:  0.6902907277338989
#
# Effective epoch:  94.0
# Accuracy:  25.0 %
# Cost:  0.6902511631973788
#
# Effective epoch:  95.0
# Accuracy:  25.0 %
# Cost:  0.6902111040387866
#
# Effective epoch:  96.0
# Accuracy:  25.0 %
# Cost:  0.6901705382491741
#
# Effective epoch:  97.0
# Accuracy:  25.0 %
# Cost:  0.6901294538580519
#
# Effective epoch:  98.0
# Accuracy:  25.0 %
# Cost:  0.6900878389175262
#
# Effective epoch:  99.0
# Accuracy:  25.0 %
# Cost:  0.6900456814871414
#
# Effective epoch:  100.0
# Accuracy:  25.0 %
# Cost:  0.6900029696193779
#
# Effective epoch:  101.0
# Accuracy:  25.0 %
# Cost:  0.6899596913457601
#
# Effective epoch:  102.0
# Accuracy:  25.0 %
# Cost:  0.6899158346635318
#
# Effective epoch:  103.0
# Accuracy:  25.0 %
# Cost:  0.689871387522853
#
# Effective epoch:  104.0
# Accuracy:  25.0 %
# Cost:  0.6898263378144844
#
# Effective epoch:  105.0
# Accuracy:  25.0 %
# Cost:  0.6897806733579199
#
# Effective epoch:  106.0
# Accuracy:  25.0 %
# Cost:  0.6897343818899322
#
# Effective epoch:  107.0
# Accuracy:  25.0 %
# Cost:  0.6896874510535003
#
# Effective epoch:  108.0
# Accuracy:  25.0 %
# Cost:  0.6896398683870899
#
# Effective epoch:  109.0
# Accuracy:  25.0 %
# Cost:  0.68959162131425
#
# Effective epoch:  110.0
# Accuracy:  25.0 %
# Cost:  0.6895426971335092
#
# Effective epoch:  111.0
# Accuracy:  25.0 %
# Cost:  0.6894930830085355
#
# Effective epoch:  112.0
# Accuracy:  25.0 %
# Cost:  0.6894427659585423
#
# Effective epoch:  113.0
# Accuracy:  25.0 %
# Cost:  0.6893917328489123
#
# Effective epoch:  114.0
# Accuracy:  25.0 %
# Cost:  0.6893399703820209
#
# Effective epoch:  115.0
# Accuracy:  25.0 %
# Cost:  0.6892874650882349
#
# Effective epoch:  116.0
# Accuracy:  25.0 %
# Cost:  0.6892342033170705
#
# Effective epoch:  117.0
# Accuracy:  25.0 %
# Cost:  0.6891801712284857
#
# Effective epoch:  118.0
# Accuracy:  25.0 %
# Cost:  0.6891253547842964
#
# Effective epoch:  119.0
# Accuracy:  25.0 %
# Cost:  0.6890697397396923
#
# Effective epoch:  120.0
# Accuracy:  25.0 %
# Cost:  0.6890133116348423
#
# Effective epoch:  121.0
# Accuracy:  25.0 %
# Cost:  0.6889560557865657
#
# Effective epoch:  122.0
# Accuracy:  25.0 %
# Cost:  0.6888979572800648
#
# Effective epoch:  123.0
# Accuracy:  25.0 %
# Cost:  0.6888390009606937
#
# Effective epoch:  124.0
# Accuracy:  25.0 %
# Cost:  0.6887791714257581
#
# Effective epoch:  125.0
# Accuracy:  25.0 %
# Cost:  0.6887184530163262
#
# Effective epoch:  126.0
# Accuracy:  25.0 %
# Cost:  0.6886568298090439
#
# Effective epoch:  127.0
# Accuracy:  25.0 %
# Cost:  0.6885942856079352
#
# Effective epoch:  128.0
# Accuracy:  25.0 %
# Cost:  0.6885308039361838
#
# Effective epoch:  129.0
# Accuracy:  25.0 %
# Cost:  0.688466368027875
#
# Effective epoch:  130.0
# Accuracy:  25.0 %
# Cost:  0.6884009608196962
#
# Effective epoch:  131.0
# Accuracy:  25.0 %
# Cost:  0.6883345649425767
#
# Effective epoch:  132.0
# Accuracy:  25.0 %
# Cost:  0.6882671627132619
#
# Effective epoch:  133.0
# Accuracy:  25.0 %
# Cost:  0.6881987361258078
#
# Effective epoch:  134.0
# Accuracy:  25.0 %
# Cost:  0.6881292668429874
#
# Effective epoch:  135.0
# Accuracy:  25.0 %
# Cost:  0.6880587361875978
#
# Effective epoch:  136.0
# Accuracy:  25.0 %
# Cost:  0.6879871251336594
#
# Effective epoch:  137.0
# Accuracy:  25.0 %
# Cost:  0.6879144142974948
#
# Effective epoch:  138.0
# Accuracy:  25.0 %
# Cost:  0.6878405839286794
#
# Effective epoch:  139.0
# Accuracy:  25.0 %
# Cost:  0.6877656139008552
#
# Effective epoch:  140.0
# Accuracy:  25.0 %
# Cost:  0.6876894837023942
#
# Effective epoch:  141.0
# Accuracy:  25.0 %
# Cost:  0.6876121724269063
#
# Effective epoch:  142.0
# Accuracy:  25.0 %
# Cost:  0.6875336587635763
#
# Effective epoch:  143.0
# Accuracy:  25.0 %
# Cost:  0.6874539209873276
#
# Effective epoch:  144.0
# Accuracy:  25.0 %
# Cost:  0.6873729369487969
#
# Effective epoch:  145.0
# Accuracy:  25.0 %
# Cost:  0.6872906840641103
#
# Effective epoch:  146.0
# Accuracy:  50.0 %
# Cost:  0.6872071393044563
#
# Effective epoch:  147.0
# Accuracy:  50.0 %
# Cost:  0.6871222791854381
#
# Effective epoch:  148.0
# Accuracy:  50.0 %
# Cost:  0.6870360797562004
#
# Effective epoch:  149.0
# Accuracy:  50.0 %
# Cost:  0.6869485165883191
#
# Effective epoch:  150.0
# Accuracy:  50.0 %
# Cost:  0.6868595647644405
#
# Effective epoch:  151.0
# Accuracy:  50.0 %
# Cost:  0.6867691988666641
#
# Effective epoch:  152.0
# Accuracy:  50.0 %
# Cost:  0.6866773929646537
#
# Effective epoch:  153.0
# Accuracy:  50.0 %
# Cost:  0.6865841206034667
#
# Effective epoch:  154.0
# Accuracy:  50.0 %
# Cost:  0.6864893547910931
#
# Effective epoch:  155.0
# Accuracy:  50.0 %
# Cost:  0.686393067985686
#
# Effective epoch:  156.0
# Accuracy:  50.0 %
# Cost:  0.6862952320824791
#
# Effective epoch:  157.0
# Accuracy:  50.0 %
# Cost:  0.6861958184003718
#
# Effective epoch:  158.0
# Accuracy:  50.0 %
# Cost:  0.6860947976681744
#
# Effective epoch:  159.0
# Accuracy:  50.0 %
# Cost:  0.6859921400104962
#
# Effective epoch:  160.0
# Accuracy:  50.0 %
# Cost:  0.6858878149332657
#
# Effective epoch:  161.0
# Accuracy:  50.0 %
# Cost:  0.6857817913088677
#
# Effective epoch:  162.0
# Accuracy:  50.0 %
# Cost:  0.6856740373608816
#
# Effective epoch:  163.0
# Accuracy:  50.0 %
# Cost:  0.6855645206484098
#
# Effective epoch:  164.0
# Accuracy:  50.0 %
# Cost:  0.6854532080499744
#
# Effective epoch:  165.0
# Accuracy:  50.0 %
# Cost:  0.6853400657469737
#
# Effective epoch:  166.0
# Accuracy:  50.0 %
# Cost:  0.6852250592066753
#
# Effective epoch:  167.0
# Accuracy:  50.0 %
# Cost:  0.6851081531647324
#
# Effective epoch:  168.0
# Accuracy:  50.0 %
# Cost:  0.6849893116072057
#
# Effective epoch:  169.0
# Accuracy:  50.0 %
# Cost:  0.6848684977520697
#
# Effective epoch:  170.0
# Accuracy:  50.0 %
# Cost:  0.6847456740301872
#
# Effective epoch:  171.0
# Accuracy:  50.0 %
# Cost:  0.6846208020657303
#
# Effective epoch:  172.0
# Accuracy:  50.0 %
# Cost:  0.6844938426560292
#
# Effective epoch:  173.0
# Accuracy:  50.0 %
# Cost:  0.6843647557508262
#
# Effective epoch:  174.0
# Accuracy:  50.0 %
# Cost:  0.684233500430913
#
# Effective epoch:  175.0
# Accuracy:  50.0 %
# Cost:  0.684100034886129
#
# Effective epoch:  176.0
# Accuracy:  50.0 %
# Cost:  0.683964316392697
#
# Effective epoch:  177.0
# Accuracy:  50.0 %
# Cost:  0.6838263012898708
#
# Effective epoch:  178.0
# Accuracy:  50.0 %
# Cost:  0.6836859449558699
#
# Effective epoch:  179.0
# Accuracy:  50.0 %
# Cost:  0.6835432017830755
#
# Effective epoch:  180.0
# Accuracy:  50.0 %
# Cost:  0.6833980251524572
#
# Effective epoch:  181.0
# Accuracy:  50.0 %
# Cost:  0.6832503674072082
#
# Effective epoch:  182.0
# Accuracy:  50.0 %
# Cost:  0.6831001798255504
#
# Effective epoch:  183.0
# Accuracy:  50.0 %
# Cost:  0.6829474125926875
#
# Effective epoch:  184.0
# Accuracy:  50.0 %
# Cost:  0.6827920147718702
#
# Effective epoch:  185.0
# Accuracy:  50.0 %
# Cost:  0.6826339342745373
#
# Effective epoch:  186.0
# Accuracy:  50.0 %
# Cost:  0.6824731178295058
#
# Effective epoch:  187.0
# Accuracy:  50.0 %
# Cost:  0.6823095109511679
#
# Effective epoch:  188.0
# Accuracy:  50.0 %
# Cost:  0.6821430579066611
#
# Effective epoch:  189.0
# Accuracy:  50.0 %
# Cost:  0.6819737016819728
#
# Effective epoch:  190.0
# Accuracy:  50.0 %
# Cost:  0.6818013839469388
#
# Effective epoch:  191.0
# Accuracy:  50.0 %
# Cost:  0.6816260450190939
#
# Effective epoch:  192.0
# Accuracy:  50.0 %
# Cost:  0.6814476238263356
#
# Effective epoch:  193.0
# Accuracy:  50.0 %
# Cost:  0.6812660578683509
#
# Effective epoch:  194.0
# Accuracy:  50.0 %
# Cost:  0.6810812831767656
#
# Effective epoch:  195.0
# Accuracy:  50.0 %
# Cost:  0.680893234273964
#
# Effective epoch:  196.0
# Accuracy:  50.0 %
# Cost:  0.6807018441305339
#
# Effective epoch:  197.0
# Accuracy:  50.0 %
# Cost:  0.6805070441212819
#
# Effective epoch:  198.0
# Accuracy:  50.0 %
# Cost:  0.6803087639797691
#
# Effective epoch:  199.0
# Accuracy:  50.0 %
# Cost:  0.6801069317513099
#
# Effective epoch:  200.0
# Accuracy:  50.0 %
# Cost:  0.6799014737443779
#
# Effective epoch:  201.0
# Accuracy:  50.0 %
# Cost:  0.6796923144803634
#
# Effective epoch:  202.0
# Accuracy:  50.0 %
# Cost:  0.6794793766416131
#
# Effective epoch:  203.0
# Accuracy:  50.0 %
# Cost:  0.6792625810177004
#
# Effective epoch:  204.0
# Accuracy:  50.0 %
# Cost:  0.6790418464498501
#
# Effective epoch:  205.0
# Accuracy:  50.0 %
# Cost:  0.6788170897734587
#
# Effective epoch:  206.0
# Accuracy:  50.0 %
# Cost:  0.6785882257586342
#
# Effective epoch:  207.0
# Accuracy:  50.0 %
# Cost:  0.6783551670486887
#
# Effective epoch:  208.0
# Accuracy:  50.0 %
# Cost:  0.6781178240965036
#
# Effective epoch:  209.0
# Accuracy:  50.0 %
# Cost:  0.6778761050986963
#
# Effective epoch:  210.0
# Accuracy:  50.0 %
# Cost:  0.677629915927504
#
# Effective epoch:  211.0
# Accuracy:  50.0 %
# Cost:  0.6773791600603045
#
# Effective epoch:  212.0
# Accuracy:  50.0 %
# Cost:  0.6771237385066907
#
# Effective epoch:  213.0
# Accuracy:  50.0 %
# Cost:  0.6768635497330076
#
# Effective epoch:  214.0
# Accuracy:  50.0 %
# Cost:  0.6765984895842649
#
# Effective epoch:  215.0
# Accuracy:  50.0 %
# Cost:  0.676328451203331
#
# Effective epoch:  216.0
# Cost:  0.6311371064517844
#
# Effective epoch:  288.0
# Accuracy:  100.0 %
# Cost:  0.6298439704080089
#
# Effective epoch:  289.0
# Accuracy:  100.0 %
# Cost:  0.6285185340199221
#
# Effective epoch:  290.0
# Accuracy:  100.0 %
# Cost:  0.6271598958911273
#
# Effective epoch:  291.0
# Accuracy:  100.0 %
# Cost:  0.6257671314346454
#
# Effective epoch:  292.0
# Accuracy:  100.0 %
# Cost:  0.6243392926997696
#
# Effective epoch:  293.0
# Accuracy:  100.0 %
# Cost:  0.6228754082474753
#
# Effective epoch:  294.0
# Accuracy:  100.0 %
# Cost:  0.6213744830802749
#
# Effective epoch:  295.0
# Accuracy:  100.0 %
# Cost:  0.6198354986328592
#
# Effective epoch:  296.0
# Accuracy:  100.0 %
# Cost:  0.6182574128303459
#
# Effective epoch:  297.0
# Accuracy:  100.0 %
# Cost:  0.6166391602214398
#
# Effective epoch:  298.0
# Accuracy:  100.0 %
# Cost:  0.6149796521943263
#
# Effective epoch:  299.0
# Accuracy:  100.0 %
# Cost:  0.6132777772836367
#
# Effective epoch:  300.0
# Accuracy:  100.0 %
# Cost:  0.6115324015773607
#
# Effective epoch:  301.0
# Accuracy:  100.0 %
# Cost:  0.6097423692331199
#
# Effective epoch:  302.0
# Accuracy:  100.0 %
# Cost:  0.6079065031137643
#
# Effective epoch:  303.0
# Accuracy:  100.0 %
# Cost:  0.6060236055527913
#
# Effective epoch:  304.0
# Accuracy:  100.0 %
# Cost:  0.6040924592606232
#
# Effective epoch:  305.0
# Accuracy:  100.0 %
# Cost:  0.6021118283832952
#
# Effective epoch:  306.0
# Accuracy:  100.0 %
# Cost:  0.6000804597255991
#
# Effective epoch:  307.0
# Accuracy:  100.0 %
# Cost:  0.5979970841511846
#
# Effective epoch:  308.0
# Accuracy:  100.0 %
# Cost:  0.5958604181725354
#
# Effective epoch:  309.0
# Accuracy:  100.0 %
# Cost:  0.5936691657440893
#
# Effective epoch:  310.0
# Accuracy:  100.0 %
# Cost:  0.5914220202720535
#
# Effective epoch:  311.0
# Accuracy:  100.0 %
# Cost:  0.5891176668546618
#
# Effective epoch:  312.0
# Accuracy:  100.0 %
# Cost:  0.586754784766705
#
# Effective epoch:  313.0
# Accuracy:  100.0 %
# Cost:  0.5843320502021276
#
# Effective epoch:  314.0
# Accuracy:  100.0 %
# Cost:  0.5818481392883079
#
# Effective epoch:  315.0
# Accuracy:  100.0 %
# Cost:  0.579301731385275
#
# Effective epoch:  316.0
# Accuracy:  100.0 %
# Cost:  0.5766915126825829
#
# Effective epoch:  317.0
# Accuracy:  100.0 %
# Cost:  0.574016180105796
#
# Effective epoch:  318.0
# Accuracy:  100.0 %
# Cost:  0.5712744455435379
#
# Effective epoch:  319.0
# Accuracy:  100.0 %
# Cost:  0.5684650404047776
#
# Effective epoch:  320.0
# Accuracy:  100.0 %
# Cost:  0.565586720514461
#
# Effective epoch:  321.0
# Accuracy:  100.0 %
# Cost:  0.5626382713536922
#
# Effective epoch:  322.0
# Accuracy:  100.0 %
# Cost:  0.5596185136484259
#
# Effective epoch:  323.0
# Accuracy:  100.0 %
# Cost:  0.556526309308009
#
# Effective epoch:  324.0
# Accuracy:  100.0 %
# Cost:  0.553360567711888
#
# Effective epoch:  325.0
# Accuracy:  100.0 %
# Cost:  0.5501202523393656
#
# Effective epoch:  326.0
# Accuracy:  100.0 %
# Cost:  0.5468043877334224
#
# Effective epoch:  327.0
# Accuracy:  100.0 %
# Cost:  0.5434120667853206
#
# Effective epoch:  328.0
# Accuracy:  100.0 %
# Cost:  0.5399424583219645
#
# Effective epoch:  329.0
# Accuracy:  100.0 %
# Cost:  0.5363948149728207
#
# Effective epoch:  330.0
# Accuracy:  100.0 %
# Cost:  0.5327684812876269
#
# Effective epoch:  331.0
# Accuracy:  100.0 %
# Cost:  0.5290629020701443
#
# Effective epoch:  332.0
# Accuracy:  100.0 %
# Cost:  0.5252776308869201
#
# Effective epoch:  333.0
# Accuracy:  100.0 %
# Cost:  0.5214123387034387
#
# Effective epoch:  334.0
# Accuracy:  100.0 %
# Cost:  0.5174668225932557
#
# Effective epoch:  335.0
# Accuracy:  100.0 %
# Cost:  0.5134410144588083
#
# Effective epoch:  336.0
# Accuracy:  100.0 %
# Cost:  0.5093349896956861
#
# Effective epoch:  337.0
# Accuracy:  100.0 %
# Cost:  0.5051489757253527
#
# Effective epoch:  338.0
# Accuracy:  100.0 %
# Cost:  0.500883360314778
#
# Effective epoch:  339.0
# Accuracy:  100.0 %
# Cost:  0.49653869959533403
#
# Effective epoch:  340.0
# Accuracy:  100.0 %
# Cost:  0.4921157256877752
#
# Effective epoch:  341.0
# Accuracy:  100.0 %
# Cost:  0.4876153538353917
#
# Effective epoch:  342.0
# Accuracy:  100.0 %
# Cost:  0.483038688943642
#
# Effective epoch:  343.0
# Accuracy:  100.0 %
# Cost:  0.47838703142196504
#
# Effective epoch:  344.0
# Accuracy:  100.0 %
# Cost:  0.47366188222221745
#
# Effective epoch:  345.0
# Accuracy:  100.0 %
# Cost:  0.46886494696849085
#
# Effective epoch:  346.0
# Accuracy:  100.0 %
# Cost:  0.4639981390750722
#
# Effective epoch:  347.0
# Accuracy:  100.0 %
# Cost:  0.4590635817532125
#
# Effective epoch:  348.0
# Accuracy:  100.0 %
# Cost:  0.4540636088132504
#
# Effective epoch:  349.0
# Accuracy:  100.0 %
# Cost:  0.44900076417660706
#
# Effective epoch:  350.0
# Accuracy:  100.0 %
# Cost:  0.44387780002224864
#
# Effective epoch:  351.0
# Accuracy:  100.0 %
# Cost:  0.4386976735044111
#
# Effective epoch:  352.0
# Accuracy:  100.0 %
# Cost:  0.4334635419926024
#
# Effective epoch:  353.0
# Accuracy:  100.0 %
# Cost:  0.4281787568010467
#
# Effective epoch:  354.0
# Accuracy:  100.0 %
# Cost:  0.4228468553925735
#
# Effective epoch:  355.0
# Accuracy:  100.0 %
# Cost:  0.41747155206127023
#
# Effective epoch:  356.0
# Accuracy:  100.0 %
# Cost:  0.41205672711865343
#
# Effective epoch:  357.0
# Accuracy:  100.0 %
# Cost:  0.4066064146293154
#
# Effective epoch:  358.0
# Accuracy:  100.0 %
# Accuracy:  100.0 %
# Cost:  0.21833004970927303
#
# Effective epoch:  395.0
# Accuracy:  100.0 %
# Cost:  0.214379109320008
#
# Effective epoch:  396.0
# Accuracy:  100.0 %
# Cost:  0.2105065491510204
#
# Effective epoch:  397.0
# Accuracy:  100.0 %
# Cost:  0.20671207463906766
#
# Effective epoch:  398.0
# Accuracy:  100.0 %
# Cost:  0.20299527104389933
#
# Effective epoch:  399.0
# Accuracy:  100.0 %
# Cost:  0.19935561245846922
#
# Effective epoch:  400.0
# Accuracy:  100.0 %
# Cost:  0.1957924706895071
#
# Effective epoch:  401.0
# Accuracy:  100.0 %
# Cost:  0.19230512395454924
#
# Effective epoch:  402.0
# Accuracy:  100.0 %
# Cost:  0.18889276534903227
#
# Effective epoch:  403.0
# Accuracy:  100.0 %
# Cost:  0.1855545110442687
#
# Effective epoch:  404.0
# Accuracy:  100.0 %
# Cost:  0.18228940818397416
#
# Effective epoch:  405.0
# Accuracy:  100.0 %
# Cost:  0.17909644245343964
#
# Effective epoch:  406.0
# Accuracy:  100.0 %
# Cost:  0.17597454530139361
#
# Effective epoch:  407.0
# Accuracy:  100.0 %
# Cost:  0.17292260080005512
#
# Effective epoch:  408.0
# Accuracy:  100.0 %
# Cost:  0.16993945213381906
#
# Effective epoch:  409.0
# Accuracy:  100.0 %
# Cost:  0.16702390771144152
#
# Effective epoch:  410.0
# Accuracy:  100.0 %
# Cost:  0.16417474690051087
#
# Effective epoch:  411.0
# Accuracy:  100.0 %
# Cost:  0.16139072538641627
#
# Effective epoch:  412.0
# Accuracy:  100.0 %
# Cost:  0.15867058016097726
#
# Effective epoch:  413.0
# Accuracy:  100.0 %
# Cost:  0.15601303414841078
#
# Effective epoch:  414.0
# Accuracy:  100.0 %
# Cost:  0.15341680047840267
#
# Effective epoch:  415.0
# Accuracy:  100.0 %
# Cost:  0.1508805864177674
#
# Effective epoch:  416.0
# Accuracy:  100.0 %
# Cost:  0.14840309697353832
#
# Effective epoch:  417.0
# Accuracy:  100.0 %
# Cost:  0.1459830381813821
#
# Effective epoch:  418.0
# Accuracy:  100.0 %
# Cost:  0.1436191200939928
#
# Effective epoch:  419.0
# Accuracy:  100.0 %
# Cost:  0.14131005948464034
#
# Effective epoch:  420.0
# Accuracy:  100.0 %
# Cost:  0.13905458228133846
#
# Effective epoch:  421.0
# Accuracy:  100.0 %
# Cost:  0.1368514257472127
#
# Effective epoch:  422.0
# Accuracy:  100.0 %
# Cost:  0.13469934042258255
#
# Effective epoch:  423.0
# Accuracy:  100.0 %
# Cost:  0.1325970918440864
#
# Effective epoch:  424.0
# Accuracy:  100.0 %
# Cost:  0.1305434620558675
#
# Effective epoch:  425.0
# Accuracy:  100.0 %
# Cost:  0.1285372509274354
#
# Effective epoch:  426.0
# Accuracy:  100.0 %
# Cost:  0.12657727729234552
#
# Effective epoch:  427.0
# Accuracy:  100.0 %
# Cost:  0.12466237992129964
#
# Effective epoch:  428.0
# Accuracy:  100.0 %
# Cost:  0.1227914183426984
#
# Effective epoch:  429.0
# Accuracy:  100.0 %
# Cost:  0.12096327352305983
#
# Effective epoch:  430.0
# Accuracy:  100.0 %
# Cost:  0.11917684841909738
#
# Effective epoch:  431.0
# Accuracy:  100.0 %
# Cost:  0.11743106841260564
#
# Effective epoch:  432.0
# Accuracy:  100.0 %
# Cost:  0.11572488163866514
#
# Effective epoch:  433.0
# Accuracy:  100.0 %
# Cost:  0.1140572592170378
#
# Effective epoch:  434.0
# Accuracy:  100.0 %
# Cost:  0.11242719539600186
#
# Effective epoch:  435.0
# Accuracy:  100.0 %
# Cost:  0.11083370761726008
#
# Effective epoch:  436.0
# Accuracy:  100.0 %
# Cost:  0.10927583650996377
#
# Effective epoch:  437.0
# Accuracy:  100.0 %
# Cost:  0.1077526458213246
#
# Effective epoch:  438.0
# Accuracy:  100.0 %
# Cost:  0.10626322229073205
#
# Effective epoch:  439.0
# Accuracy:  100.0 %
# Cost:  0.10480667547377766
#
# Effective epoch:  440.0
# Accuracy:  100.0 %
# Cost:  0.10338213752208147
#
# Effective epoch:  441.0
# Accuracy:  100.0 %
# Cost:  0.10198876292435029
#
# Effective epoch:  442.0
# Accuracy:  100.0 %
# Cost:  0.10062572821364713
#
# Effective epoch:  443.0
# Accuracy:  100.0 %
# Cost:  0.09929223164543403
#
# Effective epoch:  444.0
# Accuracy:  100.0 %
# Cost:  0.09798749285055687
#
# Effective epoch:  445.0
# Accuracy:  100.0 %
# Cost:  0.09671075246697197
#
# Effective epoch:  446.0
# Accuracy:  100.0 %
# Cost:  0.09546127175367139
#
# Effective epoch:  447.0
# Accuracy:  100.0 %
# Cost:  0.09423833218994267
#
# Effective epoch:  448.0
# Accuracy:  100.0 %
# Cost:  0.09304123506280344
#
# Effective epoch:  449.0
# Accuracy:  100.0 %
# Cost:  0.09186930104517543
#
# Effective epoch:  450.0
# Accuracy:  100.0 %
# Cost:  0.09072186976710571
#
# Effective epoch:  451.0
# Accuracy:  100.0 %
# Cost:  0.08959829938211157
#
# Effective epoch:  452.0
# Accuracy:  100.0 %
# Cost:  0.08849796613050402
#
# Effective epoch:  453.0
# Accuracy:  100.0 %
# Cost:  0.08742026390135164
#
# Effective epoch:  454.0
# Accuracy:  100.0 %
# Cost:  0.08636460379455682
#
# Effective epoch:  455.0
# Accuracy:  100.0 %
# Cost:  0.08533041368435444
#
# Effective epoch:  456.0
# Accuracy:  100.0 %
# Cost:  0.08431713778538656
#
# Effective epoch:  457.0
# Accuracy:  100.0 %
# Cost:  0.08332423622236786
#
# Effective epoch:  458.0
# Accuracy:  100.0 %
# Cost:  0.08235118460422808
#
# Effective epoch:  459.0
# Accuracy:  100.0 %
# Cost:  0.08139747360350189
#
# Effective epoch:  460.0
# Accuracy:  100.0 %
# Cost:  0.08046260854163237
#
# Effective epoch:  461.0
# Accuracy:  100.0 %
# Cost:  0.07954610898075498
#
# Effective epoch:  462.0
# Accuracy:  100.0 %
# Cost:  0.07864750832244706
#
# Effective epoch:  463.0
# Accuracy:  100.0 %
# Cost:  0.07776635341384472
#
# Effective epoch:  464.0
# Accuracy:  100.0 %
# Cost:  0.07690220416146266
#
# Effective epoch:  465.0
# Accuracy:  100.0 %
# Cost:  0.07605463315298547
#
# Effective epoch:  466.0
# Accuracy:  100.0 %
# Cost:  0.07522322528724412
#
# Effective epoch:  467.0
# Accuracy:  100.0 %
# Cost:  0.0744075774125396
#
# Effective epoch:  468.0
# Accuracy:  100.0 %
# Cost:  0.07360729797342931
#
# Effective epoch:  469.0
# Accuracy:  100.0 %
# Cost:  0.0728220066660519
#
# Effective epoch:  470.0
# Accuracy:  100.0 %
# Cost:  0.0720513341020307
#
# Effective epoch:  471.0
# Accuracy:  100.0 %
# Cost:  0.07129492148096107
#
# Effective epoch:  472.0
# Accuracy:  100.0 %
# Cost:  0.07055242027146291
#
# Effective epoch:  473.0
# Accuracy:  100.0 %
# Cost:  0.06982349190075093
#
# Effective epoch:  474.0
# Accuracy:  100.0 %
# Cost:  0.06910780745265516
#
# Effective epoch:  475.0
# Accuracy:  100.0 %
# Cost:  0.06840504737400566
#
# Effective epoch:  476.0
# Accuracy:  100.0 %
# Cost:  0.06771490118927882
#
# Effective epoch:  477.0
# Accuracy:  100.0 %
# Cost:  0.0670370672233859
#
# Effective epoch:  478.0
# Accuracy:  100.0 %
# Cost:  0.06637125233247766
#
# Effective epoch:  479.0
# Accuracy:  100.0 %
# Cost:  0.06571717164262394
#
# Effective epoch:  480.0
# Accuracy:  100.0 %
# Cost:  0.06507454829622022
#
# Effective epoch:  481.0
# Accuracy:  100.0 %
# Cost:  0.06444311320596768
#
# Effective epoch:  482.0
# Accuracy:  100.0 %
# Cost:  0.06382260481626546
#
# Effective epoch:  483.0
# Accuracy:  100.0 %
# Cost:  0.0632127688718505
#
# Effective epoch:  484.0
# Accuracy:  100.0 %
# Cost:  0.06261335819351627
#
# Effective epoch:  485.0
# Accuracy:  100.0 %
# Cost:  0.06202413246074201
#
# Effective epoch:  486.0
# Accuracy:  100.0 %
# Cost:  0.06144485800105742
#
# Effective epoch:  487.0
# Accuracy:  100.0 %
# Cost:  0.060875307585972094
#
# Effective epoch:  488.0
# Accuracy:  100.0 %
# Cost:  0.060315260233296905
#
# Effective epoch:  489.0
# Accuracy:  100.0 %
# Cost:  0.0597645010156834
#
# Effective epoch:  490.0
# Accuracy:  100.0 %
# Cost:  0.05922282087521162
#
# Effective epoch:  491.0
# Accuracy:  100.0 %
# Cost:  0.05869001644385517
#
# Effective epoch:  492.0
# Accuracy:  100.0 %
# Cost:  0.05816588986965629
#
# Effective epoch:  493.0
# Accuracy:  100.0 %
# Cost:  0.057650248648444334
#
# Effective epoch:  494.0
# Accuracy:  100.0 %
# Cost:  0.05714290546093462
#
# Effective epoch:  495.0
# Accuracy:  100.0 %
# Cost:  0.056643678015047536
#
# Effective epoch:  496.0
# Accuracy:  100.0 %
# Cost:  0.05615238889328858
#
# Effective epoch:  497.0
# Accuracy:  100.0 %
# Cost:  0.05566886540503557
#
# Effective epoch:  498.0
# Accuracy:  100.0 %
# Cost:  0.055192939443581994
#
# Effective epoch:  499.0
# Accuracy:  100.0 %
# Cost:  0.054724447347787364
#
# Effective epoch:  500.0
# Accuracy:  100.0 %
# Cost:  0.0542632297681897
#
# Effective epoch:  501.0
# Accuracy:  100.0 %
# Cost:  0.05380913153744035
#
# Effective epoch:  502.0
# Accuracy:  100.0 %
# Cost:  0.05336200154492057
#
# Effective epoch:  503.0
# Accuracy:  100.0 %
# Cost:  0.05292169261540964
#
# Effective epoch:  504.0
# Accuracy:  100.0 %
# Cost:  0.05248806139166916
#
# Effective epoch:  505.0
# Accuracy:  100.0 %
# Cost:  0.05206096822082051
#
# Effective epoch:  506.0
# Accuracy:  100.0 %
# Cost:  0.05164027704438915
#
# Effective epoch:  507.0
# Accuracy:  100.0 %
# Cost:  0.05122585529189716
#
# Effective epoch:  508.0
# Accuracy:  100.0 %
# Cost:  0.0508175737778863
#
# Effective epoch:  509.0
# Accuracy:  100.0 %
# Cost:  0.05041530660225995
#
# Effective epoch:  510.0
# Accuracy:  100.0 %
# Cost:  0.05001893105383235
#
# Effective epoch:  511.0
# Accuracy:  100.0 %
# Cost:  0.04962832751697998
#
# Effective epoch:  512.0
# Accuracy:  100.0 %
# Cost:  0.04924337938129129
#
# Effective epoch:  513.0
# Accuracy:  100.0 %
# Cost:  0.04886397295411526
#
# Effective epoch:  514.0
# Accuracy:  100.0 %
# Cost:  0.04848999737591184
#
# Effective epoch:  515.0
# Accuracy:  100.0 %
# Cost:  0.04812134453830993
#
# Effective epoch:  516.0
# Accuracy:  100.0 %
# Cost:  0.04775790900478332
#
# Effective epoch:  517.0
# Accuracy:  100.0 %
# Cost:  0.047399587933855805
#
# Effective epoch:  518.0
# Accuracy:  100.0 %
# Cost:  0.04704628100475128
#
# Effective epoch:  519.0
# Accuracy:  100.0 %
# Cost:  0.046697890345405856
#
# Effective epoch:  520.0
# Accuracy:  100.0 %
# Cost:  0.04635432046276383
#
# Effective epoch:  521.0
# Accuracy:  100.0 %
# Cost:  0.04601547817527918
#
# Effective epoch:  522.0
# Accuracy:  100.0 %
# Cost:  0.04568127254754975
#
# Effective epoch:  523.0
# Accuracy:  100.0 %
# Cost:  0.04535161482701213
#
# Effective epoch:  524.0
# Accuracy:  100.0 %
# Cost:  0.045026418382626374
#
# Effective epoch:  525.0
# Accuracy:  100.0 %
# Cost:  0.04470559864548675
#
# Effective epoch:  526.0
# Accuracy:  100.0 %
# Cost:  0.044389073051290404
#
# Effective epoch:  527.0
# Accuracy:  100.0 %
# Cost:  0.044076760984604134
#
# Effective epoch:  528.0
# Accuracy:  100.0 %
# Cost:  0.043768583724867485
#
# Effective epoch:  529.0
# Accuracy:  100.0 %
# Cost:  0.04346446439407427
#
# Effective epoch:  530.0
# Accuracy:  100.0 %
# Cost:  0.04316432790607658
#
# Effective epoch:  531.0
# Accuracy:  100.0 %
# Cost:  0.042868100917456686
#
# Effective epoch:  532.0
# Accuracy:  100.0 %
# Cost:  0.04257571177991455
#
# Effective epoch:  533.0
# Accuracy:  100.0 %
# Cost:  0.04228709049411953
#
# Effective epoch:  534.0
# Accuracy:  100.0 %
# Cost:  0.042002168664979286
#
# Effective epoch:  535.0
# Accuracy:  100.0 %
# Cost:  0.04172087945827683
#
# Effective epoch:  536.0
# Accuracy:  100.0 %
# Cost:  0.04144315755863034
#
# Effective epoch:  537.0
# Accuracy:  100.0 %
# Cost:  0.04116893912873395
#
# Effective epoch:  538.0
# Accuracy:  100.0 %
# Cost:  0.040898161769833685
#
# Effective epoch:  539.0
# Accuracy:  100.0 %
# Cost:  0.04063076448340065
#
# Effective epoch:  540.0
# Accuracy:  100.0 %
# Cost:  0.04036668763396023
#
# Effective epoch:  541.0
# Accuracy:  100.0 %
# Cost:  0.040105872913039395
#
# Effective epoch:  542.0
# Accuracy:  100.0 %
# Cost:  0.039848263304196
#
# Effective epoch:  543.0
# Accuracy:  100.0 %
# Cost:  0.039593803049093476
#
# Effective epoch:  544.0
# Accuracy:  100.0 %
# Cost:  0.039342437614587736
#
# Effective epoch:  545.0
# Accuracy:  100.0 %
# Cost:  0.039094113660792275
#
# Effective epoch:  546.0
# Accuracy:  100.0 %
# Cost:  0.038848779010089596
#
# Effective epoch:  547.0
# Accuracy:  100.0 %
# Cost:  0.038606382617059176
#
# Effective epoch:  548.0
# Accuracy:  100.0 %
# Cost:  0.03836687453929055
#
# Effective epoch:  549.0
# Accuracy:  100.0 %
# Cost:  0.0381302059090538
#
# Effective epoch:  550.0
# Accuracy:  100.0 %
# Cost:  0.03789632890579992
#
# Effective epoch:  551.0
# Accuracy:  100.0 %
# Cost:  0.03766519672946314
#
# Effective epoch:  552.0
# Accuracy:  100.0 %
# Cost:  0.03743676357454041
#
# Effective epoch:  553.0
# Accuracy:  100.0 %
# Cost:  0.037210984604922975
#
# Effective epoch:  554.0
# Accuracy:  100.0 %
# Cost:  0.03698781592945481
#
# Effective epoch:  555.0
# Accuracy:  100.0 %
# Cost:  0.0367672145781962
#
# Effective epoch:  556.0
# Accuracy:  100.0 %
# Cost:  0.03654913847936919
#
# Effective epoch:  557.0
# Accuracy:  100.0 %
# Cost:  0.03633354643696255
#
# Effective epoch:  558.0
# Accuracy:  100.0 %
# Cost:  0.03612039810897698
#
# Effective epoch:  559.0
# Accuracy:  100.0 %
# Cost:  0.03590965398628866
#
# Effective epoch:  560.0
# Accuracy:  100.0 %
# Cost:  0.035701275372112304
#
# Effective epoch:  561.0
# Accuracy:  100.0 %
# Cost:  0.035495224362045226
#
# Effective epoch:  562.0
# Accuracy:  100.0 %
# Cost:  0.03529146382467312
#
# Effective epoch:  563.0
# Accuracy:  100.0 %
# Cost:  0.03508995738272091
#
# Effective epoch:  564.0
# Accuracy:  100.0 %
# Cost:  0.03489066939473126
#
# Effective epoch:  565.0
# Accuracy:  100.0 %
# Cost:  0.034693564937254076
#
# Effective epoch:  566.0
# Accuracy:  100.0 %
# Cost:  0.03449860978753165
#
# Effective epoch:  567.0
# Accuracy:  100.0 %
# Cost:  0.03430577040666362
#
# Effective epoch:  568.0
# Accuracy:  100.0 %
# Cost:  0.03411501392323678
#
# Effective epoch:  569.0
# Accuracy:  100.0 %
# Cost:  0.033926308117406406
#
# Effective epoch:  570.0
# Accuracy:  100.0 %
# Cost:  0.033739621405413665
#
# Effective epoch:  571.0
# Accuracy:  100.0 %
# Cost:  0.033554922824527184
# Accuracy:  100.0 %
# Cost:  0.028011438978653578
#
# Effective epoch:  608.0
# Accuracy:  100.0 %
# Cost:  0.027883093343361202
#
# Effective epoch:  609.0
# Accuracy:  100.0 %
# Cost:  0.027755904443402882
#
# Effective epoch:  610.0
# Accuracy:  100.0 %
# Cost:  0.0276298571558246
#
# Effective epoch:  611.0
# Accuracy:  100.0 %
# Cost:  0.027504936612759157
#
# Effective epoch:  612.0
# Accuracy:  100.0 %
# Cost:  0.02738112819621135
#
# Effective epoch:  613.0
# Accuracy:  100.0 %
# Cost:  0.027258417532968704
#
# Effective epoch:  614.0
# Accuracy:  100.0 %
# Cost:  0.02713679048963149
#
# Effective epoch:  615.0
# Accuracy:  100.0 %
# Cost:  0.027016233167761115
#
# Effective epoch:  616.0
# Accuracy:  100.0 %
# Cost:  0.026896731899143073
#
# Effective epoch:  617.0
# Accuracy:  100.0 %
# Cost:  0.02677827324116062
#
# Effective epoch:  618.0
# Accuracy:  100.0 %
# Cost:  0.026660843972277373
#
# Effective epoch:  619.0
# Accuracy:  100.0 %
# Cost:  0.026544431087625046
#
# Effective epoch:  620.0
# Accuracy:  100.0 %
# Cost:  0.026429021794694127
#
# Effective epoch:  621.0
# Accuracy:  100.0 %
# Cost:  0.026314603509124297
#
# Effective epoch:  622.0
# Accuracy:  100.0 %
# Cost:  0.026201163850592755
#
# Effective epoch:  623.0
# Accuracy:  100.0 %
# Cost:  0.02608869063879633
#
# Effective epoch:  624.0
# Accuracy:  100.0 %
# Cost:  0.02597717188952718
#
# Effective epoch:  625.0
# Accuracy:  100.0 %
# Cost:  0.02586659581083743
#
# Effective epoch:  626.0
# Accuracy:  100.0 %
# Cost:  0.025756950799291866
#
# Effective epoch:  627.0
# Accuracy:  100.0 %
# Cost:  0.025648225436305613
#
# Effective epoch:  628.0
# Accuracy:  100.0 %
# Cost:  0.02554040848456514
#
# Effective epoch:  629.0
# Accuracy:  100.0 %
# Cost:  0.025433488884530515
#
# Effective epoch:  630.0
# Accuracy:  100.0 %
# Cost:  0.025327455751015627
#
# Effective epoch:  631.0
# Accuracy:  100.0 %
# Cost:  0.025222298369846213
#
# Effective epoch:  632.0
# Accuracy:  100.0 %
# Cost:  0.0251180061945924
#
# Effective epoch:  633.0
# Accuracy:  100.0 %
# Cost:  0.02501456884337398
#
# Effective epoch:  634.0
# Accuracy:  100.0 %
# Cost:  0.024911976095737184
#
# Effective epoch:  635.0
# Accuracy:  100.0 %
# Cost:  0.02481021788960069
#
# Effective epoch:  636.0
# Accuracy:  100.0 %
# Cost:  0.024709284318269065
#
# Effective epoch:  637.0
# Accuracy:  100.0 %
# Cost:  0.024609165627512086
#
# Effective epoch:  638.0
# Accuracy:  100.0 %
# Cost:  0.024509852212708808
#
# Effective epoch:  639.0
# Accuracy:  100.0 %
# Cost:  0.024411334616053392
#
# Effective epoch:  640.0
# Accuracy:  100.0 %
# Cost:  0.024313603523822294
#
# Effective epoch:  641.0
# Accuracy:  100.0 %
# Cost:  0.02421664976370181
#
# Effective epoch:  642.0
# Accuracy:  100.0 %
# Cost:  0.024120464302172094
# Cost:  0.0056567788027446185
#
# Effective epoch:  1495.0
# Accuracy:  100.0 %
# Cost:  0.005651872385964016
#
# Effective epoch:  1496.0
# Accuracy:  100.0 %
# Cost:  0.005646974761107927
#
# Effective epoch:  1497.0
# Accuracy:  100.0 %
# Cost:  0.005642085904273009
#
# Effective epoch:  1498.0
# Accuracy:  100.0 %
# Cost:  0.005637205791642666
#
# Effective epoch:  1499.0
# Accuracy:  100.0 %
# Cost:  0.005632334399487425
#
# Effective epoch:  1500.0
# Accuracy:  100.0 %
# Cost:  0.00562747170416346
#
# Time Taken:  1.5572407245635986  seconds
# Accuracy:  100.0
# Text(0.5,0.92,'XOR Decision Surface using Logistic Sigmoid')

# %%
# Part - b Generate Dataset
np.random.seed(100)
X = np.sort(2*np.random.rand(50,1)-1)
t = np.sin(2*(np.pi)*X) + 0.3*np.random.randn(50,1)

# Part - b Regression
np.random.seed(100)
X = np.sort(2*np.random.rand(50,1)-1)
t = np.sin(2*(np.pi)*X) + 0.3*np.random.randn(50,1)


# Build NN with 20 hidden units
NN2 = DeepNN([1,2,1], activations=['tanh','identity'],epsilon=0.9)
w = NN2.learn(epochs=50000, learning_rate=0.001, X=X, y=t, cost_func='least_squares', metrics_at=10000, optimizer='rmsprop',batch_size=50)
plt.title('Regression with 20 Hidden Units Cost Function')

# plot the model
x_mesh = np.linspace(np.min(X),np.max(X),500).reshape(500,1)
y = NN2.think(x_mesh)


plt.figure()
plt.plot(x_mesh,y,'r')
plt.scatter(X,t)
plt.title('Regression with 20 hidden Units')

# Build NN with 20 hidden units
plt.figure()
NN2 = DeepNN([1,20,1], activations=['tanh','identity'],epsilon=2.1)
w = NN2.learn(epochs=10000, learning_rate=0.001, X=X, y=t, cost_func='least_squares', metrics_at=1000, optimizer='rmsprop',batch_size=5)
plt.title('Regression with 20 Hidden Units Cost Function')

# plot the model
x_mesh = np.linspace(np.min(X)-0.25,np.max(X)+0.25,500).reshape(500,1)
y = NN2.think(x_mesh)

plt.figure()
plt.plot(x_mesh,y,'r')
plt.scatter(X,t)
plt.title('Regression with 20 hidden Units')

plt.show()
# Out:
# Effective epoch:  1.0
# Cost:  3.1317798715079705
#
# Effective epoch:  2.0
# Cost:  0.27795264419758237
#
# Effective epoch:  3.0
# Cost:  0.2775079686788257
#
# Effective epoch:  4.0
# Cost:  0.2776002342414044
#
# Effective epoch:  5.0
# Cost:  0.2775911170999268
#
# Time Taken:  2.34637713432312  seconds
# Effective epoch:  1.0
# Cost:  396.47760431701613
#
# Effective epoch:  2.0
# Cost:  0.47417302928671945
#
# Effective epoch:  3.0
# Cost:  0.07054090319896972
#
# Effective epoch:  4.0
# Cost:  0.06008800353331953
#
# Effective epoch:  5.0
# Cost:  0.05624840916375845
#
# Effective epoch:  6.0
# Cost:  0.05303074203864415
#
# Effective epoch:  7.0
# Cost:  0.05034360928254886
#
# Effective epoch:  8.0
# Cost:  0.048179013061423
#
# Effective epoch:  9.0
# Cost:  0.04648709606895887
#
# Effective epoch:  10.0
# Cost:  0.044756804232995856
#
# Time Taken:  4.655504941940308  seconds
